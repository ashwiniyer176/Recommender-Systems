# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("./data/movies_metadata.csv")
# Out:
# C:\Users\Ashwin\AppData\Local\Temp\ipykernel_13452\855968984.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("./data/movies_metadata.csv")

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# 45464  False                                                NaN         0
# 45465  False                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df.drop(columns=["imdb_id","id","belongs_to_collection","homepage","tagline","spoken_languages","production_countries","production_companies","poster_path"], inplace=True)

# %%
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (44349, 17)

# %%
df
# Out:
#        adult    budget                                             genres  \
# 0      False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      False         0                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...       ...                                                ...
# 45460  False         0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45462  False         0                      [{'id': 18, 'name': 'Drama'}]
# 45463  False         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464  False         0                                                 []
# 45465  False         0                                                 []
#
#            id    imdb_id original_language               original_title  \
# ...

# %%
df=df[df['genres']!="[]"]

# %%
import re

# %%
df['primary_genre']=df['genres'].apply(lambda genre:int(re.search(r"[0-9]+",genre).group()))
# Out:
# C:\Users\Ashwin\AppData\Local\Temp\ipykernel_13452\4063725885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['primary_genre']=df['genres'].apply(lambda genre:int(re.search(r"[0-9]+",genre).group()))

# %%
df
# Out:
#        adult    budget                                             genres  \
# 0      False  30000000  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      False  65000000  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      False         0  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      False  16000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4      False         0                     [{'id': 35, 'name': 'Comedy'}]
# ...      ...       ...                                                ...
# 45458  False         0                     [{'id': 27, 'name': 'Horror'}]
# 45459  False         0           [{'id': 878, 'name': 'Science Fiction'}]
# 45460  False         0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 45462  False         0                      [{'id': 18, 'name': 'Drama'}]
# 45463  False         0  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
#
#            id    imdb_id original_language               original_title  \
# ...
